# %% [markdown]
# #  This python code is for submission to Applied Data Science Capstone Project Week 3 Assignment

# %% [markdown]
# ### The first part of this code is to scrape data from a wikipedia website with information on Toronto neighborhoods and zip codes and remove rows with borough or neighbourhood unassinged

# %%
import pandas as pd

url = 'https://en.wikipedia.org/wiki/List_of_postal_codes_of_Canada:_M'
webdata = pd.read_html(url)
webdata[0].to_csv('Canadian_Postal_Codes.csv')

# %%
print(len(webdata))
# Out:
# 3

# %%
webdata[0]
# Out:
#     Postal Code           Borough  \
# 0           M1A      Not assigned
# 1           M2A      Not assigned
# 2           M3A        North York
# 3           M4A        North York
# 4           M5A  Downtown Toronto
# ..          ...               ...
# 175         M5Z      Not assigned
# 176         M6Z      Not assigned
# 177         M7Z      Not assigned
# 178         M8Z         Etobicoke
# 179         M9Z      Not assigned
#
#                                          Neighbourhood
# 0                                         Not assigned
# 1                                         Not assigned
# 2                                            Parkwoods
# 3                                     Victoria Village
# 4                            Regent Park, Harbourfront
# ..                                                 ...
# 175                                       Not assigned
# 176                                       Not assigned
# ...

# %% [markdown]
# ### Take first data table from website to a dataframe

# %%
webdata1=webdata[0]

# %%
tordata = webdata1[['Postal Code','Borough','Neighbourhood']]

# %% [markdown]
# ### make sure it is a datafrma and look at result

# %%
print(type(tordata))
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %%
tordata
# Out:
#     Postal Code           Borough  \
# 0           M1A      Not assigned
# 1           M2A      Not assigned
# 2           M3A        North York
# 3           M4A        North York
# 4           M5A  Downtown Toronto
# ..          ...               ...
# 175         M5Z      Not assigned
# 176         M6Z      Not assigned
# 177         M7Z      Not assigned
# 178         M8Z         Etobicoke
# 179         M9Z      Not assigned
#
#                                          Neighbourhood
# 0                                         Not assigned
# 1                                         Not assigned
# 2                                            Parkwoods
# 3                                     Victoria Village
# 4                            Regent Park, Harbourfront
# ..                                                 ...
# 175                                       Not assigned
# 176                                       Not assigned
# ...

# %% [markdown]
# ### Need to remove Not assigned rows.  Will create another data frame to work on and check

# %%
tordata_test = tordata
tordata_test.to_csv('Toronto_Data.csv')

# %%
tordata_test
# Out:
#     Postal Code           Borough  \
# 0           M1A      Not assigned
# 1           M2A      Not assigned
# 2           M3A        North York
# 3           M4A        North York
# 4           M5A  Downtown Toronto
# ..          ...               ...
# 175         M5Z      Not assigned
# 176         M6Z      Not assigned
# 177         M7Z      Not assigned
# 178         M8Z         Etobicoke
# 179         M9Z      Not assigned
#
#                                          Neighbourhood
# 0                                         Not assigned
# 1                                         Not assigned
# 2                                            Parkwoods
# 3                                     Victoria Village
# 4                            Regent Park, Harbourfront
# ..                                                 ...
# 175                                       Not assigned
# 176                                       Not assigned
# ...

# %% [markdown]
# # will try one method to see if it works

# %%
tordata_use=tordata_test

# %%
tordata_use.drop(tordata_use.index[tordata_use['Borough'] == 'Not assigned'], inplace = True)

# %%
tordata_use
# Out:
#     Postal Code           Borough  \
# 2           M3A        North York
# 3           M4A        North York
# 4           M5A  Downtown Toronto
# 5           M6A        North York
# 6           M7A  Downtown Toronto
# ..          ...               ...
# 160         M8X         Etobicoke
# 165         M4Y  Downtown Toronto
# 168         M7Y      East Toronto
# 169         M8Y         Etobicoke
# 178         M8Z         Etobicoke
#
#                                          Neighbourhood
# 2                                            Parkwoods
# 3                                     Victoria Village
# 4                            Regent Park, Harbourfront
# 5                     Lawrence Manor, Lawrence Heights
# 6          Queen's Park, Ontario Provincial Government
# ..                                                 ...
# 160      The Kingsway, Montgomery Road, Old Mill North
# 165                               Church and Wellesley
# ...

# %% [markdown]
# ### This seems to give dataframe in form desired

# %% [markdown]
# ### check shape of final data fram to use

# %%
tordata_use.shape
# Out:
# (103, 3)

# %% [markdown]
# # Begin Question-Part II

# %% [markdown]
# # Tried to import GeoCoder, but could not find it

# %% [markdown]
# import geocoder # import geocoder
#
#  initialize your variable to None
# lat_lng_coords = None
#
#  loop until you get the coordinates
# while(lat_lng_coords is None):
#   g = geocoder.google('{}, Toronto, Ontario'.format(postal_code))
#   lat_lng_coords = g.latlng
#
# latitude = lat_lng_coords[0]
# longitude = lat_lng_coords[1]
# print(lattitude,longitude)

# %% [markdown]
# # Will use csv file instead

# %%
url2 = 'http://cocl.us/Geospatial_data'

# %%
neigh_lat_long = pd.read_csv(url2)
neigh_lat_long
neigh_lat_long.to_csv('PostalLatLong.csv')

# %%
print(type(neigh_lat_long))
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %%
tordata_use
# Out:
#     Postal Code           Borough  \
# 2           M3A        North York
# 3           M4A        North York
# 4           M5A  Downtown Toronto
# 5           M6A        North York
# 6           M7A  Downtown Toronto
# ..          ...               ...
# 160         M8X         Etobicoke
# 165         M4Y  Downtown Toronto
# 168         M7Y      East Toronto
# 169         M8Y         Etobicoke
# 178         M8Z         Etobicoke
#
#                                          Neighbourhood
# 2                                            Parkwoods
# 3                                     Victoria Village
# 4                            Regent Park, Harbourfront
# 5                     Lawrence Manor, Lawrence Heights
# 6          Queen's Park, Ontario Provincial Government
# ..                                                 ...
# 160      The Kingsway, Montgomery Road, Old Mill North
# 165                               Church and Wellesley
# ...

# %%
tordata_test = tordata_use

# %%
tordata_test['Latitude'] = 0.0

# %%
tordata_test['Longitude'] = 0.0

# %% [markdown]
# ## Add Longitude and Latitude columns to data frame

# %%
tordata_test
# Out:
#     Postal Code           Borough  \
# 2           M3A        North York
# 3           M4A        North York
# 4           M5A  Downtown Toronto
# 5           M6A        North York
# 6           M7A  Downtown Toronto
# ..          ...               ...
# 160         M8X         Etobicoke
# 165         M4Y  Downtown Toronto
# 168         M7Y      East Toronto
# 169         M8Y         Etobicoke
# 178         M8Z         Etobicoke
#
#                                          Neighbourhood  Latitude  Longitude
# 2                                            Parkwoods       0.0        0.0
# 3                                     Victoria Village       0.0        0.0
# 4                            Regent Park, Harbourfront       0.0        0.0
# 5                     Lawrence Manor, Lawrence Heights       0.0        0.0
# 6          Queen's Park, Ontario Provincial Government       0.0        0.0
# ..                                                 ...       ...        ...
# ...

# %%
range = len(tordata_test)
print(range)
# Out:
# 103

# %%
pc_tor=tordata_test['Postal Code']
pc_tor
# Out:
# 2      M3A
# 3      M4A
# 4      M5A
# 5      M6A
# 6      M7A
#       ...
# 160    M8X
# 165    M4Y
# 168    M7Y
# 169    M8Y
# 178    M8Z
# Name: Postal Code, Length: 103, dtype: object

# %%
pc_list=neigh_lat_long['Postal Code']
pc_list
# Out:
# 0      M1B
# 1      M1C
# 2      M1E
# 3      M1G
# 4      M1H
#       ...
# 98     M9N
# 99     M9P
# 100    M9R
# 101    M9V
# 102    M9W
# Name: Postal Code, Length: 103, dtype: object

# %%
#for PC in tordata_test:
for x in tordata_test:
    print(tordata_test['Postal Code'].loc)

# %%
tordata_use
# Out:
#     Postal Code           Borough  \
# 2           M3A        North York
# 3           M4A        North York
# 4           M5A  Downtown Toronto
# 5           M6A        North York
# 6           M7A  Downtown Toronto
# ..          ...               ...
# 160         M8X         Etobicoke
# 165         M4Y  Downtown Toronto
# 168         M7Y      East Toronto
# 169         M8Y         Etobicoke
# 178         M8Z         Etobicoke
#
#                                          Neighbourhood  Latitude  Longitude
# 2                                            Parkwoods       0.0        0.0
# 3                                     Victoria Village       0.0        0.0
# 4                            Regent Park, Harbourfront       0.0        0.0
# 5                     Lawrence Manor, Lawrence Heights       0.0        0.0
# 6          Queen's Park, Ontario Provincial Government       0.0        0.0
# ..                                                 ...       ...        ...
# ...

# %%
import numpy as np

# %% [markdown]
# ### Could not figure out how to combine the data in python, but commined the data in Excel and will upload the combined data from the csv file

# %%
torontodata=pd.read_csv('Toronto_Neighborhood_LatLong.csv')

# %%
torontodata
# Out:
#     Postal Code      Borough  \
# 0           M1B  Scarborough
# 1           M1C  Scarborough
# 2           M1E  Scarborough
# 3           M1G  Scarborough
# 4           M1H  Scarborough
# ..          ...          ...
# 98          M9N         York
# 99          M9P    Etobicoke
# 100         M9R    Etobicoke
# 101         M9V    Etobicoke
# 102         M9W    Etobicoke
#
#                                          Neighbourhood   Latitude  Longitude
# 0                                       Malvern, Rouge  43.806686 -79.194353
# 1               Rouge Hill, Port Union, Highland Creek  43.784535 -79.160497
# 2                    Guildwood, Morningside, West Hill  43.763573 -79.188711
# 3                                               Woburn  43.770992 -79.216917
# 4                                            Cedarbrae  43.773136 -79.239476
# ..                                                 ...        ...        ...
# ...
